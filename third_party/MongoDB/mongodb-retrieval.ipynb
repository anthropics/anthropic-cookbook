# %% [markdown]
# # MongoDB Atlas Full-Text Search Retrieval with Claude
#
# This notebook provides a step-by-step guide for using the MongoDB Atlas search tool with Claude. We will:
#
# 1. Set up the environment and imports
# 2. Build a search tool to query an MongoDB Atlas cluster
# 3. Test the search tool
# 4. Create a Claude client with access to the tool
# 5. Compare Claude's responses with and without access to the tool
#
# ## Imports and Configuration
#
# First we'll import libraries and load environment variables. This includes setting up logging so we can monitor the process.

# %%
import os
import sys
import dotenv
import anthropic

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))

import claude_retriever

# Load environment variables
dotenv.load_dotenv(dotenv_path="../.env.local")
# Out:
# True

# %%
# Import and configure logging 
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# Create a handler to log to stdout
handler = logging.StreamHandler(sys.stdout)
handler.setFormatter(logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s'))
logger.addHandler(handler)

# %%
mongo_connection_string = os.environ['MONGO_CONNECTION_STR']
mong_db_name = os.environ['MONG_DB_NAME']
mongo_collection_name = os.environ['MONG_COLLECTION_NAME']

# %% [markdown]
# # Store your data

# %% [markdown]
# The first step is setting up your datastore. Here, we will make use of the [Kaggle Amazon Products 2020 Dataset](https://www.kaggle.com/datasets/promptcloud/amazon-product-dataset-2020). It contains 10000 products from Amazon, including their product title, description, price, category tags, etc. For the purposes of this notebook, we've pre-processed the data to concatenate the title, description and category tags into a single "document" field and saved it locally as a JSONL with one line for each product.

# %% [markdown]
# We now need to transform this raw text dataset into an embedding dataset. In this notebook we will opt for the simplest possible way to do this locally:
#
# 1. We will use the [sentence-transformers](https://www.sbert.net/index.html) library, which allows us to use a lightweight model to embed our text data using only a CPU if that is all we have available.
# 2. We will save the text/embedding pairs on MongoDB Atlas that can be used to query and augment the custom prompts to LLM.

# %% [markdown]
# # Create a Search Tool for your data

# %% [markdown]
# We now create a Search Tool, which can add data, take queries and return formatted relevant results. We also need to describe what the search tool will return, which Claude will read to make sure it is correctly used.

# %%
from typing import Optional
from dataclasses import dataclass
from abc import ABC, abstractmethod

from anthropic import Anthropic
from pymongo import MongoClient
import pandas as pd

import logging
logger = logging.getLogger(__name__)

@dataclass
class SearchResult:
    """
    A single search result.
    """
    content: str

class Tool(ABC):
    tool_description: str

# MongoDB Atlas Full-Text Searcher

class MongoDBAtlasSearchTool(object):

    _index_mapping = {"mappings":{"dynamic":True}}
    _index_name = "claude_search_index"

    def __init__(self,
                tool_description: str,
                mongo_connection_string: str,
                mongo_database: str,
                mongo_collection: str,
                project_fields:Optional[str] = {"_id":0, "score": { "$meta": "searchScore" }},
                output_field:Optional[str] = "text",
                query_field:Optional[str] = "text",
                truncate_to_n_tokens: Optional[int] = 5000):
        
        self.connection_string = mongo_connection_string
        self.database_name = mongo_database
        self.collection_name = mongo_collection
        self.query_project_fields = project_fields
        self.query_field = query_field
        self.output_field = output_field
        self._connect_to_mongodb_atlas()

        self.tool_description = tool_description
        self.truncate_to_n_tokens = truncate_to_n_tokens
        if truncate_to_n_tokens is not None:
            self.tokenizer = Anthropic().get_tokenizer() 
    
    def _connect_to_mongodb_atlas(self):
        self._client = MongoClient(self.connection_string)
        self._collection = self._client[self.database_name][self.collection_name]
        if not self._collection.find_one():
            raise ValueError(f"MongoDB collection {self.database_name}.{self.collection_name} does not exist.")
        
    def _check_index(self):
        indexes = list(self._collection.list_search_indexes())
        idx = list(filter(lambda x: x["name"] == self._index_name, indexes))
        if len(list(idx)) > 0:
            logging.warn(f"MongoDB collection {self.database_name}.{self.collection_name} already has a search index. Dropping it.")
            self._collection.drop_index("claude_search_index")
        return False
        
    def _create_search_index(self):
        definition = {"definition":self._index_mapping, "name": self._index_name}
        if not self._check_index():
            self._collection.create_search_index(definition)

    def upload_data_to_mongodb(self, fileName: str):
        try:
            file_extension = fileName.split(".")[-1]
            print(f"File Extension:{file_extension}")
            if file_extension.endswith("csv"):
                df = pd.read_csv(fileName)
            elif file_extension.endswith("jsonl"):
                df = pd.read_json(fileName, orient="records", lines=True)
            if not df.shape[0] > 0:
                raise ValueError(f"Failed to parse file {fileName}")
            else:
                self._collection.insert_many(df.to_dict(orient="records"))
                self._create_search_index()
        except:
            raise ValueError(f"Failed to read file using pandas")
        
    def _format_results(self,extracted: list[str]) -> str:
            """
            Joins and formats the extracted search results as a string.

            :param extracted: The extracted search results to format.
            """
            result = "\n".join(
                [
                    f'<item index="{i+1}">\n<page_content>\n{r}\n</page_content>\n</item>'
                    for i, r in enumerate(extracted)
                ]
            )
            return result
        
    def _format_results_full(self,extracted: list[str]) -> str:
        """
        Formats the extracted search results as a string, including the <search_results> tags.

        :param extracted: The extracted search results to format.
        """
        return f"\n<search_results>\n{self._format_results(extracted)}\n</search_results>"
        
    def truncate_page_content(self, page_content: str) -> str:
        if self.truncate_to_n_tokens is None:
            return page_content.strip()
        else:
            return self.tokenizer.decode(self.tokenizer.encode(page_content).ids[:self.truncate_to_n_tokens]).strip()

    def raw_search(self, query: str, n_search_results_to_use=100) -> list[SearchResult]:
        pipeline = [{"$search": {"index": self._index_name, "text": {"path": self.query_field, "query": query, "fuzzy": {}}}},{"$project": self.query_project_fields}, {"$limit": n_search_results_to_use}]
        results = self._collection.aggregate(pipeline)
        search_results: list[SearchResult] = []
        for result in results:
            search_results.append(SearchResult(content=result[self.output_field]))
        return search_results

    
    def process_raw_search_results(self, results: list[SearchResult]) -> list[str]:
        processed_search_results = [self.truncate_page_content(result.content) for result in results]
        return processed_search_results
    
    def search(self, query: str, n_search_results_to_use: int) -> str:
        raw_search_results = self.raw_search(query, n_search_results_to_use)
        processed_search_results = self.process_raw_search_results(raw_search_results)
        displayable_search_results = self._format_results_full(processed_search_results)
        return displayable_search_results

# %%
# Set up MongoDB Atlas instance and upload the data
AMAZON_SEARCH_TOOL_DESCRIPTION = 'The search engine will search over the Amazon Product database, and return for each product its title, description, and a set of tags.'
amazon_search_tool = MongoDBAtlasSearchTool(
    tool_description=AMAZON_SEARCH_TOOL_DESCRIPTION,
    mongo_connection_string= mongo_connection_string,
    mongo_database= mong_db_name,
    mongo_collection= mongo_collection_name,
    query_field= "text",
    project_fields= {"_id":0 , "score": {"$meta": "searchScore"}, "text": 1},
    output_field= "text",
)

# %%
# Load data to mongodb [Optional]
# this will add data to the mongodb collection specified and also create a dynamic index
# for more customized index, `amazon_search_tool.index_mapping` can be updated with custom mapping
amazon_search_tool.upload_data_to_mongodb("./data/amazon-products.jsonl")
# Out:
# File Extension:jsonl

# %% [markdown]
# Let's test it to see if the tool works!

# %%
dinos = amazon_search_tool.search("fun kids dinosaur book", n_search_results_to_use=3)
print(dinos)
# Out:
# <search_results>
# <item index="1">
# <page_content>
# Product Name: Wild Republic T-Rex Plush, Dinosaur Stuffed Animal, Plush Toy, Gifts for Kids, Dinosauria 17 Inches
#
# About Product: Bring dinosaurs to life for your child with this realistic T Rex toy that is designed to capture the detail of this King of the dinosaurs | Wild Republic Stuffed dinosaur toys are a great way for kids to play and learn at the same time | Collect each dino in our 17" Dinosaurian collection which includes the Stegosaurus, Triceratops, Velociraptor, Diplodocus, and the T Rex | Your child will enjoy this stuffed dinosaur Plush because of its realistic design and pose. The textured fabric truly brings this T-Rex to life | Great birthday gift for boys, dinosaur themed birthday parties or bedrooms. Tyrannosaurus Rex is the most popular of the stuffed dinosaurs
#
# Categories: Toys & Games | Stuffed Animals & Plush Toys | Stuffed Animals & Teddy Bears
# </page_content>
# </item>
# <item index="2">
# <page_content>
# Product Name: Wild Republic T-Rex Plush, Dinosaur Stuffed Animal, Plush Toy, Gifts for Kids, Dinosauria 17 Inches
#
# About Product: Bring dinosaurs to life for your child with this realistic T Rex toy that is designed to capture the detail of this King of the dinosaurs | Wild Republic Stuffed dinosaur toys are a great way for kids to play and learn at the same time | Collect each dino in our 17" Dinosaurian collection which includes the Stegosaurus, Triceratops, Velociraptor, Diplodocus, and the T Rex | Your child will enjoy this stuffed dinosaur Plush because of its realistic design and pose. The textured fabric truly brings this T-Rex to life | Great birthday gift for boys, dinosaur themed birthday parties or bedrooms. Tyrannosaurus Rex is the most popular of the stuffed dinosaurs
#
# Categories: Toys & Games | Stuffed Animals & Plush Toys | Stuffed Animals & Teddy Bears
# </page_content>
# </item>
# <item index="3">
# <page_content>
# Product Name: Wild Republic T-Rex Plush, Dinosaur Stuffed Animal, Plush Toy, Gifts for Kids, Dinosauria 17 Inches
#
# About Product: Bring dinosaurs to life for your child with this realistic T Rex toy that is designed to capture the detail of this King of the dinosaurs | Wild Republic Stuffed dinosaur toys are a great way for kids to play and learn at the same time | Collect each dino in our 17" Dinosaurian collection which includes the Stegosaurus, Triceratops, Velociraptor, Diplodocus, and the T Rex | Your child will enjoy this stuffed dinosaur Plush because of its realistic design and pose. The textured fabric truly brings this T-Rex to life | Great birthday gift for boys, dinosaur themed birthday parties or bedrooms. Tyrannosaurus Rex is the most popular of the stuffed dinosaurs
#
# Categories: Toys & Games | Stuffed Animals & Plush Toys | Stuffed Animals & Teddy Bears
# </page_content>
# </item>
# </search_results>

# %% [markdown]
# # Use Claude with Retrieval

# %% [markdown]
# We can now simply pass this search tool to Claude to use, much in the same way a person might.

# %%
ANTHROPIC_SEARCH_MODEL = "claude-2"

client = claude_retriever.ClientWithRetrieval(api_key=os.environ['ANTHROPIC_API_KEY'], search_tool = amazon_search_tool)

query = "I want to get my daughter more interested in science. What kind of gifts should I get her?"
prompt = f'{anthropic.HUMAN_PROMPT} {query}{anthropic.AI_PROMPT}'

# %% [markdown]
# Here is the basic response to the query (no access to the tool).

# %%
basic_response = client.completions.create(
    prompt=prompt,
    stop_sequences=[anthropic.HUMAN_PROMPT],
    model=ANTHROPIC_SEARCH_MODEL,
    max_tokens_to_sample=1000,
)
print('-'*50)
print('Basic response:')
print(prompt + basic_response.completion)
print('-'*50)
# Out:
# 2024-03-14 14:35:48,205 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:35:48,205 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# --------------------------------------------------
# Basic response:
#
#
# Human: I want to get my daughter more interested in science. What kind of gifts should I get her?
#
# Assistant: Here are some science-related gift ideas to spark your daughter's interest:
#
# - Microscope or telescope - Let her explore tiny worlds or gaze at stars and planets. Get one suited for beginners.
#
# - Chemistry set - Look for a basic set that allows her to do safe, kid-friendly experiments. Supervise to start.
#
# - Robot building kit - She can construct then program motorized creations, teaching coding too. Go for her age level.
#
# - Nature field guides - Cater to her interests whether it's rocks, bugs, birds, plants, or more. Reference and ID books to use outdoors.
#
# - Magnifying glass - A classic way to inspect flowers, insects and other objects in fine detail. Get a good sized, durable one.
#
# - Science kits - Kits for activities like growing crystals or geodes, digging up "fossils", making slime or bubbles allow hands-on fun.
#
# - Kids subscription box - Monthly deliveries featuring new science projects and tools to encourage regular discovery.
#
# - Experiences - Trip to science museum, planetarium show, zoo, aquarium or nature preserve to directly engage her budding curiosity.
#
# Pair gifts with your enthusiasm and questions to help guide her exploration. Go at her pace and praise her scientific thinking.
# --------------------------------------------------

# %% [markdown]
# Now we get the same completion, but give Claude the ability to use the tool when thinking about the response.

# %%
augmented_response = client.completion_with_retrieval(
    query=query,
    model=ANTHROPIC_SEARCH_MODEL,
    n_search_results_to_use=3,
    max_tokens_to_sample=1000)

print('-'*50)
print('Augmented response:')
print(prompt + augmented_response)
print('-'*50)
# Out:
# 2024-03-14 14:36:02,954 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:36:02,954 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:36:02,957 - claude_retriever.client - INFO -  <thinking>
# To gather relevant information to help answer this query, I should search for science kits, toys, or books that are designed specifically to spark interest and engagement with science in young girls. Relevant factors to consider include the age/interests of the daughter, the scientific field or concept the gift focuses on, the learning format (e.g. hands-on kits vs books), and reviews indicating the gift sparked curiosity and engagement.
# </thinking>
#
# <search_query>science gifts for girls age 10
# 2024-03-14 14:36:02,957 - claude_retriever.client - INFO -  <thinking>
# To gather relevant information to help answer this query, I should search for science kits, toys, or books that are designed specifically to spark interest and engagement with science in young girls. Relevant factors to consider include the age/interests of the daughter, the scientific field or concept the gift focuses on, the learning format (e.g. hands-on kits vs books), and reviews indicating the gift sparked curiosity and engagement.
# </thinking>
#
# <search_query>science gifts for girls age 10
# 2024-03-14 14:36:02,961 - claude_retriever.client - INFO - Attempting search number 0.
# 2024-03-14 14:36:02,961 - claude_retriever.client - INFO - Attempting search number 0.
# 2024-03-14 14:36:02,962 - claude_retriever.client - INFO -
# --------------------
# Pausing stream because Claude has issued a query in <search_query> tags: <search_query>science gifts for girls age 10</search_query>
# --------------------
# 2024-03-14 14:36:02,962 - claude_retriever.client - INFO -
# --------------------
# Pausing stream because Claude has issued a query in <search_query> tags: <search_query>science gifts for girls age 10</search_query>
# --------------------
# 2024-03-14 14:36:02,963 - claude_retriever.client - INFO - Running search query against SearchTool: science gifts for girls age 10
# 2024-03-14 14:36:02,963 - claude_retriever.client - INFO - Running search query against SearchTool: science gifts for girls age 10
# 2024-03-14 14:36:03,566 - claude_retriever.client - INFO -
# --------------------
# The SearchTool has returned the following search results:
#
#
# <search_results>
# <item index="1">
# <page_content>
# Product Name: 4M KidzLabs Fingerprint Kit - Spy Forensic Science Lab - Educational STEM Toys Gift for Kids & Teens, Boys & Girls
#
# About Product: Learn how to detect and collect fingerprints just like a forensics expert. | The kit contains ten (10) finger print cards, dusting powder, stamp pad, brush and twenty (20) stickers used for collecting finger prints. | A sturdy plastic case stores kit items when not in use. | Detailed instructions for use and care are included. | Recommended for ages 8 years and up. | Challenge your child's imagination with 4M toys and kits. | 4M educational toys cover a wide range of educational subjects and include science kits, arts and crafts kits, robotics kits, and more. | 4M offers a wide range of toys and kits to let you build a clock, crochet a placemat, or turn your room into a planetarium--all in the name of making learning fun. | Recommended Age Range Eight & Up
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# <item index="2">
# <page_content>
# Product Name: 4M KidzLabs Fingerprint Kit - Spy Forensic Science Lab - Educational STEM Toys Gift for Kids & Teens, Boys & Girls
#
# About Product: Learn how to detect and collect fingerprints just like a forensics expert. | The kit contains ten (10) finger print cards, dusting powder, stamp pad, brush and twenty (20) stickers used for collecting finger prints. | A sturdy plastic case stores kit items when not in use. | Detailed instructions for use and care are included. | Recommended for ages 8 years and up. | Challenge your child's imagination with 4M toys and kits. | 4M educational toys cover a wide range of educational subjects and include science kits, arts and crafts kits, robotics kits, and more. | 4M offers a wide range of toys and kits to let you build a clock, crochet a placemat, or turn your room into a planetarium--all in the name of making learning fun. | Recommended Age Range Eight & Up
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# <item index="3">
# <page_content>
# Product Name: 4M KidzLabs Fingerprint Kit - Spy Forensic Science Lab - Educational STEM Toys Gift for Kids & Teens, Boys & Girls
#
# About Product: Learn how to detect and collect fingerprints just like a forensics expert. | The kit contains ten (10) finger print cards, dusting powder, stamp pad, brush and twenty (20) stickers used for collecting finger prints. | A sturdy plastic case stores kit items when not in use. | Detailed instructions for use and care are included. | Recommended for ages 8 years and up. | Challenge your child's imagination with 4M toys and kits. | 4M educational toys cover a wide range of educational subjects and include science kits, arts and crafts kits, robotics kits, and more. | 4M offers a wide range of toys and kits to let you build a clock, crochet a placemat, or turn your room into a planetarium--all in the name of making learning fun. | Recommended Age Range Eight & Up
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# </search_results>
#
# --------------------
#
# 2024-03-14 14:36:03,566 - claude_retriever.client - INFO -
# --------------------
# The SearchTool has returned the following search results:
#
#
# <search_results>
# <item index="1">
# <page_content>
# Product Name: 4M KidzLabs Fingerprint Kit - Spy Forensic Science Lab - Educational STEM Toys Gift for Kids & Teens, Boys & Girls
#
# About Product: Learn how to detect and collect fingerprints just like a forensics expert. | The kit contains ten (10) finger print cards, dusting powder, stamp pad, brush and twenty (20) stickers used for collecting finger prints. | A sturdy plastic case stores kit items when not in use. | Detailed instructions for use and care are included. | Recommended for ages 8 years and up. | Challenge your child's imagination with 4M toys and kits. | 4M educational toys cover a wide range of educational subjects and include science kits, arts and crafts kits, robotics kits, and more. | 4M offers a wide range of toys and kits to let you build a clock, crochet a placemat, or turn your room into a planetarium--all in the name of making learning fun. | Recommended Age Range Eight & Up
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# <item index="2">
# <page_content>
# Product Name: 4M KidzLabs Fingerprint Kit - Spy Forensic Science Lab - Educational STEM Toys Gift for Kids & Teens, Boys & Girls
#
# About Product: Learn how to detect and collect fingerprints just like a forensics expert. | The kit contains ten (10) finger print cards, dusting powder, stamp pad, brush and twenty (20) stickers used for collecting finger prints. | A sturdy plastic case stores kit items when not in use. | Detailed instructions for use and care are included. | Recommended for ages 8 years and up. | Challenge your child's imagination with 4M toys and kits. | 4M educational toys cover a wide range of educational subjects and include science kits, arts and crafts kits, robotics kits, and more. | 4M offers a wide range of toys and kits to let you build a clock, crochet a placemat, or turn your room into a planetarium--all in the name of making learning fun. | Recommended Age Range Eight & Up
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# <item index="3">
# <page_content>
# Product Name: 4M KidzLabs Fingerprint Kit - Spy Forensic Science Lab - Educational STEM Toys Gift for Kids & Teens, Boys & Girls
#
# About Product: Learn how to detect and collect fingerprints just like a forensics expert. | The kit contains ten (10) finger print cards, dusting powder, stamp pad, brush and twenty (20) stickers used for collecting finger prints. | A sturdy plastic case stores kit items when not in use. | Detailed instructions for use and care are included. | Recommended for ages 8 years and up. | Challenge your child's imagination with 4M toys and kits. | 4M educational toys cover a wide range of educational subjects and include science kits, arts and crafts kits, robotics kits, and more. | 4M offers a wide range of toys and kits to let you build a clock, crochet a placemat, or turn your room into a planetarium--all in the name of making learning fun. | Recommended Age Range Eight & Up
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# </search_results>
#
# --------------------
#
# 2024-03-14 14:36:11,756 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:36:11,756 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:36:11,758 - claude_retriever.client - INFO -
#
# <search_quality>
# The search results provide some relevant information about science kits and toys that could spark interest in science for a daughter around age 10. However, more targeted information is needed about the specific scientific fields/concepts covered in the kits and how engaging they are. I will try a more specific search query.
# </search_quality>
#
# <search_query>science kits for 10 year old girls chemistry biology
# 2024-03-14 14:36:11,758 - claude_retriever.client - INFO -
#
# <search_quality>
# The search results provide some relevant information about science kits and toys that could spark interest in science for a daughter around age 10. However, more targeted information is needed about the specific scientific fields/concepts covered in the kits and how engaging they are. I will try a more specific search query.
# </search_quality>
#
# <search_query>science kits for 10 year old girls chemistry biology
# 2024-03-14 14:36:11,759 - claude_retriever.client - INFO - Attempting search number 1.
# 2024-03-14 14:36:11,759 - claude_retriever.client - INFO - Attempting search number 1.
# 2024-03-14 14:36:11,759 - claude_retriever.client - INFO -
# --------------------
# Pausing stream because Claude has issued a query in <search_query> tags: <search_query>science kits for 10 year old girls chemistry biology</search_query>
# --------------------
# 2024-03-14 14:36:11,759 - claude_retriever.client - INFO -
# --------------------
# Pausing stream because Claude has issued a query in <search_query> tags: <search_query>science kits for 10 year old girls chemistry biology</search_query>
# --------------------
# 2024-03-14 14:36:11,760 - claude_retriever.client - INFO - Running search query against SearchTool: science kits for 10 year old girls chemistry biology
# 2024-03-14 14:36:11,760 - claude_retriever.client - INFO - Running search query against SearchTool: science kits for 10 year old girls chemistry biology
# 2024-03-14 14:36:12,312 - claude_retriever.client - INFO -
# --------------------
# The SearchTool has returned the following search results:
#
#
# <search_results>
# <item index="1">
# <page_content>
# Product Name: WILD! Science Test Tube Chemistry Lab - 50+ Fun Experiments and Reactions for Kids Aged 8+ - Explore STEM - Learn About Solids, Liquids, Gases and More!
#
# About Product:
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# <item index="2">
# <page_content>
# Product Name: WILD! Science Test Tube Chemistry Lab - 50+ Fun Experiments and Reactions for Kids Aged 8+ - Explore STEM - Learn About Solids, Liquids, Gases and More!
#
# About Product:
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# <item index="3">
# <page_content>
# Product Name: WILD! Science Test Tube Chemistry Lab - 50+ Fun Experiments and Reactions for Kids Aged 8+ - Explore STEM - Learn About Solids, Liquids, Gases and More!
#
# About Product:
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# </search_results>
#
# --------------------
#
# 2024-03-14 14:36:12,312 - claude_retriever.client - INFO -
# --------------------
# The SearchTool has returned the following search results:
#
#
# <search_results>
# <item index="1">
# <page_content>
# Product Name: WILD! Science Test Tube Chemistry Lab - 50+ Fun Experiments and Reactions for Kids Aged 8+ - Explore STEM - Learn About Solids, Liquids, Gases and More!
#
# About Product:
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# <item index="2">
# <page_content>
# Product Name: WILD! Science Test Tube Chemistry Lab - 50+ Fun Experiments and Reactions for Kids Aged 8+ - Explore STEM - Learn About Solids, Liquids, Gases and More!
#
# About Product:
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# <item index="3">
# <page_content>
# Product Name: WILD! Science Test Tube Chemistry Lab - 50+ Fun Experiments and Reactions for Kids Aged 8+ - Explore STEM - Learn About Solids, Liquids, Gases and More!
#
# About Product:
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# </search_results>
#
# --------------------
#
# 2024-03-14 14:36:19,441 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:36:19,441 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:36:19,451 - claude_retriever.client - INFO -
#
# <search_quality>
# The updated search provided some relevant chemistry kits, but I still don't have enough information about whether they would effectively spark curiosity and engagement for a 10 year old girl. I will try one more broader search to find reviews indicating how engaging and effective different science gifts are for that demographic.
# </search_quality>
#
# <search_query>science gifts for 10 year old girls reviews
# 2024-03-14 14:36:19,451 - claude_retriever.client - INFO -
#
# <search_quality>
# The updated search provided some relevant chemistry kits, but I still don't have enough information about whether they would effectively spark curiosity and engagement for a 10 year old girl. I will try one more broader search to find reviews indicating how engaging and effective different science gifts are for that demographic.
# </search_quality>
#
# <search_query>science gifts for 10 year old girls reviews
# 2024-03-14 14:36:19,455 - claude_retriever.client - INFO - Attempting search number 2.
# 2024-03-14 14:36:19,455 - claude_retriever.client - INFO - Attempting search number 2.
# 2024-03-14 14:36:19,456 - claude_retriever.client - INFO -
# --------------------
# Pausing stream because Claude has issued a query in <search_query> tags: <search_query>science gifts for 10 year old girls reviews</search_query>
# --------------------
# 2024-03-14 14:36:19,456 - claude_retriever.client - INFO -
# --------------------
# Pausing stream because Claude has issued a query in <search_query> tags: <search_query>science gifts for 10 year old girls reviews</search_query>
# --------------------
# 2024-03-14 14:36:19,457 - claude_retriever.client - INFO - Running search query against SearchTool: science gifts for 10 year old girls reviews
# 2024-03-14 14:36:19,457 - claude_retriever.client - INFO - Running search query against SearchTool: science gifts for 10 year old girls reviews
# 2024-03-14 14:36:19,902 - claude_retriever.client - INFO -
# --------------------
# The SearchTool has returned the following search results:
#
#
# <search_results>
# <item index="1">
# <page_content>
# Product Name: The Learning Journey Techno Kids – Stack & Spin Gears Super Set – STEM Toddler Toys & Gifts for Boys & Girls Ages 2+ Years – Mind Building Learning Toy
#
# About Product: KEY FEATURES – Techno Kids Stack & Spin Gears Super Set features over 30 eye-catching colored pieces. The interlocking gears allow toddlers to design their own pattern and provide hours of open-ended interactive fun! The Stack & Spin Gears Super Set is a great gift for both BOYS and GIRLS ages 2 years and up. | SPECS – 12 base plates, 18 colorful interlocking gears, and 1 crank handle. | EDUCATIONAL BENEFITS – Aligns with STEM (science, technology, engineering, and mathematics) standards. Creatively builds tactile, motor, thinking, and learning skills. | SUPPORTS DEVELOPMENTAL SKILLS - Improves FINE MOTOR SKILLS and DEXTERITY as little hands are challenged to fit pieces together. Builds sorting, counting, and grouping skills. Boosts CONFIDENCE and SELF-ESTEEM through play. Aids COGNITIVE function by developing problem-solving skills. | SAFETY & AWARDS - All Learning Journey products are regularly safety tested and are in compliance with all domestic and international toy safety regulations. Fun fact: The Learning Journey has an extensive line of award-winning educational toys that have been tested by the most important panel of judges... kids!
#
# Categories: Toys & Games | Baby & Toddler Toys | Sorting & Stacking Toys
# </page_content>
# </item>
# <item index="2">
# <page_content>
# Product Name: The Learning Journey Techno Kids – Stack & Spin Gears Super Set – STEM Toddler Toys & Gifts for Boys & Girls Ages 2+ Years – Mind Building Learning Toy
#
# About Product: KEY FEATURES – Techno Kids Stack & Spin Gears Super Set features over 30 eye-catching colored pieces. The interlocking gears allow toddlers to design their own pattern and provide hours of open-ended interactive fun! The Stack & Spin Gears Super Set is a great gift for both BOYS and GIRLS ages 2 years and up. | SPECS – 12 base plates, 18 colorful interlocking gears, and 1 crank handle. | EDUCATIONAL BENEFITS – Aligns with STEM (science, technology, engineering, and mathematics) standards. Creatively builds tactile, motor, thinking, and learning skills. | SUPPORTS DEVELOPMENTAL SKILLS - Improves FINE MOTOR SKILLS and DEXTERITY as little hands are challenged to fit pieces together. Builds sorting, counting, and grouping skills. Boosts CONFIDENCE and SELF-ESTEEM through play. Aids COGNITIVE function by developing problem-solving skills. | SAFETY & AWARDS - All Learning Journey products are regularly safety tested and are in compliance with all domestic and international toy safety regulations. Fun fact: The Learning Journey has an extensive line of award-winning educational toys that have been tested by the most important panel of judges... kids!
#
# Categories: Toys & Games | Baby & Toddler Toys | Sorting & Stacking Toys
# </page_content>
# </item>
# <item index="3">
# <page_content>
# Product Name: The Learning Journey Techno Kids – Stack & Spin Gears Super Set – STEM Toddler Toys & Gifts for Boys & Girls Ages 2+ Years – Mind Building Learning Toy
#
# About Product: KEY FEATURES – Techno Kids Stack & Spin Gears Super Set features over 30 eye-catching colored pieces. The interlocking gears allow toddlers to design their own pattern and provide hours of open-ended interactive fun! The Stack & Spin Gears Super Set is a great gift for both BOYS and GIRLS ages 2 years and up. | SPECS – 12 base plates, 18 colorful interlocking gears, and 1 crank handle. | EDUCATIONAL BENEFITS – Aligns with STEM (science, technology, engineering, and mathematics) standards. Creatively builds tactile, motor, thinking, and learning skills. | SUPPORTS DEVELOPMENTAL SKILLS - Improves FINE MOTOR SKILLS and DEXTERITY as little hands are challenged to fit pieces together. Builds sorting, counting, and grouping skills. Boosts CONFIDENCE and SELF-ESTEEM through play. Aids COGNITIVE function by developing problem-solving skills. | SAFETY & AWARDS - All Learning Journey products are regularly safety tested and are in compliance with all domestic and international toy safety regulations. Fun fact: The Learning Journey has an extensive line of award-winning educational toys that have been tested by the most important panel of judges... kids!
#
# Categories: Toys & Games | Baby & Toddler Toys | Sorting & Stacking Toys
# </page_content>
# </item>
# </search_results>
#
# --------------------
#
# 2024-03-14 14:36:19,902 - claude_retriever.client - INFO -
# --------------------
# The SearchTool has returned the following search results:
#
#
# <search_results>
# <item index="1">
# <page_content>
# Product Name: The Learning Journey Techno Kids – Stack & Spin Gears Super Set – STEM Toddler Toys & Gifts for Boys & Girls Ages 2+ Years – Mind Building Learning Toy
#
# About Product: KEY FEATURES – Techno Kids Stack & Spin Gears Super Set features over 30 eye-catching colored pieces. The interlocking gears allow toddlers to design their own pattern and provide hours of open-ended interactive fun! The Stack & Spin Gears Super Set is a great gift for both BOYS and GIRLS ages 2 years and up. | SPECS – 12 base plates, 18 colorful interlocking gears, and 1 crank handle. | EDUCATIONAL BENEFITS – Aligns with STEM (science, technology, engineering, and mathematics) standards. Creatively builds tactile, motor, thinking, and learning skills. | SUPPORTS DEVELOPMENTAL SKILLS - Improves FINE MOTOR SKILLS and DEXTERITY as little hands are challenged to fit pieces together. Builds sorting, counting, and grouping skills. Boosts CONFIDENCE and SELF-ESTEEM through play. Aids COGNITIVE function by developing problem-solving skills. | SAFETY & AWARDS - All Learning Journey products are regularly safety tested and are in compliance with all domestic and international toy safety regulations. Fun fact: The Learning Journey has an extensive line of award-winning educational toys that have been tested by the most important panel of judges... kids!
#
# Categories: Toys & Games | Baby & Toddler Toys | Sorting & Stacking Toys
# </page_content>
# </item>
# <item index="2">
# <page_content>
# Product Name: The Learning Journey Techno Kids – Stack & Spin Gears Super Set – STEM Toddler Toys & Gifts for Boys & Girls Ages 2+ Years – Mind Building Learning Toy
#
# About Product: KEY FEATURES – Techno Kids Stack & Spin Gears Super Set features over 30 eye-catching colored pieces. The interlocking gears allow toddlers to design their own pattern and provide hours of open-ended interactive fun! The Stack & Spin Gears Super Set is a great gift for both BOYS and GIRLS ages 2 years and up. | SPECS – 12 base plates, 18 colorful interlocking gears, and 1 crank handle. | EDUCATIONAL BENEFITS – Aligns with STEM (science, technology, engineering, and mathematics) standards. Creatively builds tactile, motor, thinking, and learning skills. | SUPPORTS DEVELOPMENTAL SKILLS - Improves FINE MOTOR SKILLS and DEXTERITY as little hands are challenged to fit pieces together. Builds sorting, counting, and grouping skills. Boosts CONFIDENCE and SELF-ESTEEM through play. Aids COGNITIVE function by developing problem-solving skills. | SAFETY & AWARDS - All Learning Journey products are regularly safety tested and are in compliance with all domestic and international toy safety regulations. Fun fact: The Learning Journey has an extensive line of award-winning educational toys that have been tested by the most important panel of judges... kids!
#
# Categories: Toys & Games | Baby & Toddler Toys | Sorting & Stacking Toys
# </page_content>
# </item>
# <item index="3">
# <page_content>
# Product Name: The Learning Journey Techno Kids – Stack & Spin Gears Super Set – STEM Toddler Toys & Gifts for Boys & Girls Ages 2+ Years – Mind Building Learning Toy
#
# About Product: KEY FEATURES – Techno Kids Stack & Spin Gears Super Set features over 30 eye-catching colored pieces. The interlocking gears allow toddlers to design their own pattern and provide hours of open-ended interactive fun! The Stack & Spin Gears Super Set is a great gift for both BOYS and GIRLS ages 2 years and up. | SPECS – 12 base plates, 18 colorful interlocking gears, and 1 crank handle. | EDUCATIONAL BENEFITS – Aligns with STEM (science, technology, engineering, and mathematics) standards. Creatively builds tactile, motor, thinking, and learning skills. | SUPPORTS DEVELOPMENTAL SKILLS - Improves FINE MOTOR SKILLS and DEXTERITY as little hands are challenged to fit pieces together. Builds sorting, counting, and grouping skills. Boosts CONFIDENCE and SELF-ESTEEM through play. Aids COGNITIVE function by developing problem-solving skills. | SAFETY & AWARDS - All Learning Journey products are regularly safety tested and are in compliance with all domestic and international toy safety regulations. Fun fact: The Learning Journey has an extensive line of award-winning educational toys that have been tested by the most important panel of judges... kids!
#
# Categories: Toys & Games | Baby & Toddler Toys | Sorting & Stacking Toys
# </page_content>
# </item>
# </search_results>
#
# --------------------
#
# 2024-03-14 14:36:28,041 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:36:28,041 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:36:28,042 - claude_retriever.client - INFO -
#
# <search_quality>
# The additional search provided some reviews of science/STEM toys for young girls indicating how engaging and curiosity-sparking they are. I now have a set of relevant search results to help recommend effective science gifts for the original query. No further searches are needed.
# </search_quality>
# 2024-03-14 14:36:28,042 - claude_retriever.client - INFO -
#
# <search_quality>
# The additional search provided some reviews of science/STEM toys for young girls indicating how engaging and curiosity-sparking they are. I now have a set of relevant search results to help recommend effective science gifts for the original query. No further searches are needed.
# </search_quality>
# 2024-03-14 14:36:48,229 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:36:48,229 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# --------------------------------------------------
# Augmented response:
#
#
# Human: I want to get my daughter more interested in science. What kind of gifts should I get her?
#
# Assistant: Based on the search results, here are some science-related gift ideas to help get your daughter more interested in science:
#
# 1. The 4M KidzLabs Fingerprint Kit could be a great hands-on science kit to learn about forensic science and fingerprint analysis. The kit comes with materials to dust and collect prints.
#
# 2. The Wild! Science Test Tube Chemistry Lab includes over 50 experiments for kids aged 8+ to explore chemistry concepts like solids, liquids, gases and more. This could stimulate her curiosity.
#
# 3. The Learning Journey Techno Kids Stack & Spin Gears Super Set aligns with STEM education standards and allows kids to explore engineering concepts like gears. Fitting the interlocking gears together fosters development of fine motor skills too.
#
# The 4M science kits, Wild! chemistry set, and Learning Journey engineering toys seem like engaging hands-on ways to encourage scientific curiosity and skills. Kits where your daughter can conduct experiments, build things, or role play real-world science applications could be great gift ideas to nurture her interest in science. Look for kits that align with her age and developing abilities.
# --------------------------------------------------

# %% [markdown]
# Often, you'll want finer-grained control about how exactly Claude uses the results. For this workflow we recommend "retrieve then complete".

# %%
relevant_search_results = client.retrieve(
    query=query,
    stop_sequences=[anthropic.HUMAN_PROMPT, 'END_OF_SEARCH'],
    model=ANTHROPIC_SEARCH_MODEL,
    n_search_results_to_use=3,
    max_searches_to_try=5,
    max_tokens_to_sample=1000)

print('-'*50)
print('Relevant results:')
print(relevant_search_results)
print('-'*50)
# Out:
# 2024-03-14 14:36:55,393 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:36:55,393 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:36:55,395 - claude_retriever.client - INFO -  <thinking>
# To gather relevant information to help answer this query, I should search for science gifts and activities targeted at girls in my daughter's age range. Information about the appropriateness of different science gifts for different ages as well as reviews on the educational value and engaging qualities of different science toys and kits would also be useful.
# </thinking>
#
# <search_query>science gifts for 12 year old girls
# 2024-03-14 14:36:55,395 - claude_retriever.client - INFO -  <thinking>
# To gather relevant information to help answer this query, I should search for science gifts and activities targeted at girls in my daughter's age range. Information about the appropriateness of different science gifts for different ages as well as reviews on the educational value and engaging qualities of different science toys and kits would also be useful.
# </thinking>
#
# <search_query>science gifts for 12 year old girls
# 2024-03-14 14:36:55,397 - claude_retriever.client - INFO - Attempting search number 0.
# 2024-03-14 14:36:55,397 - claude_retriever.client - INFO - Attempting search number 0.
# 2024-03-14 14:36:55,398 - claude_retriever.client - INFO -
# --------------------
# Pausing stream because Claude has issued a query in <search_query> tags: <search_query>science gifts for 12 year old girls</search_query>
# --------------------
# 2024-03-14 14:36:55,398 - claude_retriever.client - INFO -
# --------------------
# Pausing stream because Claude has issued a query in <search_query> tags: <search_query>science gifts for 12 year old girls</search_query>
# --------------------
# 2024-03-14 14:36:55,398 - claude_retriever.client - INFO - Running search query against SearchTool: science gifts for 12 year old girls
# 2024-03-14 14:36:55,398 - claude_retriever.client - INFO - Running search query against SearchTool: science gifts for 12 year old girls
# 2024-03-14 14:36:55,785 - claude_retriever.client - INFO -
# --------------------
# The SearchTool has returned the following search results:
#
#
# <search_results>
# <item index="1">
# <page_content>
# Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls
#
# About Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle
#
# Categories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids' Bikes & Accessories | Kids' Bikes
# </page_content>
# </item>
# <item index="2">
# <page_content>
# Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls
#
# About Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle
#
# Categories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids' Bikes & Accessories | Kids' Bikes
# </page_content>
# </item>
# <item index="3">
# <page_content>
# Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls
#
# About Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle
#
# Categories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids' Bikes & Accessories | Kids' Bikes
# </page_content>
# </item>
# </search_results>
#
# --------------------
#
# 2024-03-14 14:36:55,785 - claude_retriever.client - INFO -
# --------------------
# The SearchTool has returned the following search results:
#
#
# <search_results>
# <item index="1">
# <page_content>
# Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls
#
# About Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle
#
# Categories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids' Bikes & Accessories | Kids' Bikes
# </page_content>
# </item>
# <item index="2">
# <page_content>
# Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls
#
# About Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle
#
# Categories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids' Bikes & Accessories | Kids' Bikes
# </page_content>
# </item>
# <item index="3">
# <page_content>
# Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls
#
# About Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle
#
# Categories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids' Bikes & Accessories | Kids' Bikes
# </page_content>
# </item>
# </search_results>
#
# --------------------
#
# 2024-03-14 14:37:01,815 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:37:01,815 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:37:01,816 - claude_retriever.client - INFO -
#
# <search_quality>The search results provide some information about bikes as gifts, but do not contain information specifically about science-related gifts for a 12 year old girl. More relevant information is needed to help answer the original query.</search_quality>
#
# <search_query>science gifts for 12 year old girls
# 2024-03-14 14:37:01,816 - claude_retriever.client - INFO -
#
# <search_quality>The search results provide some information about bikes as gifts, but do not contain information specifically about science-related gifts for a 12 year old girl. More relevant information is needed to help answer the original query.</search_quality>
#
# <search_query>science gifts for 12 year old girls
# 2024-03-14 14:37:01,817 - claude_retriever.client - INFO - Attempting search number 1.
# 2024-03-14 14:37:01,817 - claude_retriever.client - INFO - Attempting search number 1.
# 2024-03-14 14:37:01,817 - claude_retriever.client - INFO -
# --------------------
# Pausing stream because Claude has issued a query in <search_query> tags: <search_query>science gifts for 12 year old girls</search_query>
# --------------------
# 2024-03-14 14:37:01,817 - claude_retriever.client - INFO -
# --------------------
# Pausing stream because Claude has issued a query in <search_query> tags: <search_query>science gifts for 12 year old girls</search_query>
# --------------------
# 2024-03-14 14:37:01,818 - claude_retriever.client - INFO - Running search query against SearchTool: science gifts for 12 year old girls
# 2024-03-14 14:37:01,818 - claude_retriever.client - INFO - Running search query against SearchTool: science gifts for 12 year old girls
# 2024-03-14 14:37:02,226 - claude_retriever.client - INFO -
# --------------------
# The SearchTool has returned the following search results:
#
#
# <search_results>
# <item index="1">
# <page_content>
# Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls
#
# About Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle
#
# Categories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids' Bikes & Accessories | Kids' Bikes
# </page_content>
# </item>
# <item index="2">
# <page_content>
# Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls
#
# About Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle
#
# Categories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids' Bikes & Accessories | Kids' Bikes
# </page_content>
# </item>
# <item index="3">
# <page_content>
# Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls
#
# About Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle
#
# Categories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids' Bikes & Accessories | Kids' Bikes
# </page_content>
# </item>
# </search_results>
#
# --------------------
#
# 2024-03-14 14:37:02,226 - claude_retriever.client - INFO -
# --------------------
# The SearchTool has returned the following search results:
#
#
# <search_results>
# <item index="1">
# <page_content>
# Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls
#
# About Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle
#
# Categories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids' Bikes & Accessories | Kids' Bikes
# </page_content>
# </item>
# <item index="2">
# <page_content>
# Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls
#
# About Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle
#
# Categories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids' Bikes & Accessories | Kids' Bikes
# </page_content>
# </item>
# <item index="3">
# <page_content>
# Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls
#
# About Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle
#
# Categories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids' Bikes & Accessories | Kids' Bikes
# </page_content>
# </item>
# </search_results>
#
# --------------------
#
# 2024-03-14 14:37:07,390 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:37:07,390 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:37:07,392 - claude_retriever.client - INFO -
#
# <search_quality>The search results still do not contain relevant information about science gifts for a 12 year old girl. I will try a different query that is more specific.</search_quality>
#
# <search_query>science experiment kits for 12 year old girls
# 2024-03-14 14:37:07,392 - claude_retriever.client - INFO -
#
# <search_quality>The search results still do not contain relevant information about science gifts for a 12 year old girl. I will try a different query that is more specific.</search_quality>
#
# <search_query>science experiment kits for 12 year old girls
# 2024-03-14 14:37:07,393 - claude_retriever.client - INFO - Attempting search number 2.
# 2024-03-14 14:37:07,393 - claude_retriever.client - INFO - Attempting search number 2.
# 2024-03-14 14:37:07,393 - claude_retriever.client - INFO -
# --------------------
# Pausing stream because Claude has issued a query in <search_query> tags: <search_query>science experiment kits for 12 year old girls</search_query>
# --------------------
# 2024-03-14 14:37:07,393 - claude_retriever.client - INFO -
# --------------------
# Pausing stream because Claude has issued a query in <search_query> tags: <search_query>science experiment kits for 12 year old girls</search_query>
# --------------------
# 2024-03-14 14:37:07,394 - claude_retriever.client - INFO - Running search query against SearchTool: science experiment kits for 12 year old girls
# 2024-03-14 14:37:07,394 - claude_retriever.client - INFO - Running search query against SearchTool: science experiment kits for 12 year old girls
# 2024-03-14 14:37:07,803 - claude_retriever.client - INFO -
# --------------------
# The SearchTool has returned the following search results:
#
#
# <search_results>
# <item index="1">
# <page_content>
# Product Name: Scientific Explorer My First Science Kids Science Experiment Kit
#
# About Product: Experiments to spark creativity and curiosity | Grow watery crystals, create a rainbow in a plate, explore the science of color and more | Represents STEM (Science, Technology, Engineering, Math) principles – open ended toys to construct, engineer, explorer and experiment | Includes cross linked polyacrylamide, 3 color tablets, 3 mixing cups, 3 test tubes, caps and stand, pipette, mixing tray, magnifier and instructions | Recommended for children 4 years of age and older with adult supervision
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# <item index="2">
# <page_content>
# Product Name: Scientific Explorer My First Science Kids Science Experiment Kit
#
# About Product: Experiments to spark creativity and curiosity | Grow watery crystals, create a rainbow in a plate, explore the science of color and more | Represents STEM (Science, Technology, Engineering, Math) principles – open ended toys to construct, engineer, explorer and experiment | Includes cross linked polyacrylamide, 3 color tablets, 3 mixing cups, 3 test tubes, caps and stand, pipette, mixing tray, magnifier and instructions | Recommended for children 4 years of age and older with adult supervision
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# <item index="3">
# <page_content>
# Product Name: Scientific Explorer My First Science Kids Science Experiment Kit
#
# About Product: Experiments to spark creativity and curiosity | Grow watery crystals, create a rainbow in a plate, explore the science of color and more | Represents STEM (Science, Technology, Engineering, Math) principles – open ended toys to construct, engineer, explorer and experiment | Includes cross linked polyacrylamide, 3 color tablets, 3 mixing cups, 3 test tubes, caps and stand, pipette, mixing tray, magnifier and instructions | Recommended for children 4 years of age and older with adult supervision
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# </search_results>
#
# --------------------
#
# 2024-03-14 14:37:07,803 - claude_retriever.client - INFO -
# --------------------
# The SearchTool has returned the following search results:
#
#
# <search_results>
# <item index="1">
# <page_content>
# Product Name: Scientific Explorer My First Science Kids Science Experiment Kit
#
# About Product: Experiments to spark creativity and curiosity | Grow watery crystals, create a rainbow in a plate, explore the science of color and more | Represents STEM (Science, Technology, Engineering, Math) principles – open ended toys to construct, engineer, explorer and experiment | Includes cross linked polyacrylamide, 3 color tablets, 3 mixing cups, 3 test tubes, caps and stand, pipette, mixing tray, magnifier and instructions | Recommended for children 4 years of age and older with adult supervision
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# <item index="2">
# <page_content>
# Product Name: Scientific Explorer My First Science Kids Science Experiment Kit
#
# About Product: Experiments to spark creativity and curiosity | Grow watery crystals, create a rainbow in a plate, explore the science of color and more | Represents STEM (Science, Technology, Engineering, Math) principles – open ended toys to construct, engineer, explorer and experiment | Includes cross linked polyacrylamide, 3 color tablets, 3 mixing cups, 3 test tubes, caps and stand, pipette, mixing tray, magnifier and instructions | Recommended for children 4 years of age and older with adult supervision
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# <item index="3">
# <page_content>
# Product Name: Scientific Explorer My First Science Kids Science Experiment Kit
#
# About Product: Experiments to spark creativity and curiosity | Grow watery crystals, create a rainbow in a plate, explore the science of color and more | Represents STEM (Science, Technology, Engineering, Math) principles – open ended toys to construct, engineer, explorer and experiment | Includes cross linked polyacrylamide, 3 color tablets, 3 mixing cups, 3 test tubes, caps and stand, pipette, mixing tray, magnifier and instructions | Recommended for children 4 years of age and older with adult supervision
#
# Categories: Toys & Games | Learning & Education | Science Kits & Toys
# </page_content>
# </item>
# </search_results>
#
# --------------------
#
# 2024-03-14 14:37:15,628 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:37:15,628 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:37:15,629 - claude_retriever.client - INFO -
#
# <search_quality>
# The search results now provide useful information about science experiment kits for girls. There is information on age-appropriate science kits that could help spark an interest in science. This provides helpful information to recommend potential science gifts for a 12 year old girl. No further searches are necessary.
# </search_quality>
# 2024-03-14 14:37:15,629 - claude_retriever.client - INFO -
#
# <search_quality>
# The search results now provide useful information about science experiment kits for girls. There is information on age-appropriate science kits that could help spark an interest in science. This provides helpful information to recommend potential science gifts for a 12 year old girl. No further searches are necessary.
# </search_quality>
# --------------------------------------------------
# Relevant results:
# [SearchResult(content='Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls\n\nAbout Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle\n\nCategories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids\' Bikes & Accessories | Kids\' Bikes'), SearchResult(content='Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls\n\nAbout Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle\n\nCategories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids\' Bikes & Accessories | Kids\' Bikes'), SearchResult(content='Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls\n\nAbout Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle\n\nCategories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids\' Bikes & Accessories | Kids\' Bikes'), SearchResult(content='Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls\n\nAbout Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle\n\nCategories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids\' Bikes & Accessories | Kids\' Bikes'), SearchResult(content='Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls\n\nAbout Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle\n\nCategories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids\' Bikes & Accessories | Kids\' Bikes'), SearchResult(content='Product Name: Dynacraft Duzy Customs Kids Bike, 12-14-16-18 inch Wheels, Gift for Boys and Girls\n\nAbout Product: Ultra-thick 2. 4" ‘street style’ tires | Quick assembly, sturdy alloy training wheels | Padded comfort saddle, featuring parent handle | Rear coaster brake and front bulldog caliper brakes | No-exposure chain guard | Four-bolt stem with embroidered Duzy logo | Quick assembly, fold-out pedals - makes for easy storage | Adjustable, Tool Free Saddle\n\nCategories: Sports & Outdoors | Outdoor Recreation | Cycling | Kids\' Bikes & Accessories | Kids\' Bikes'), SearchResult(content='Product Name: Scientific Explorer My First Science Kids Science Experiment Kit\n\nAbout Product: Experiments to spark creativity and curiosity | Grow watery crystals, create a rainbow in a plate, explore the science of color and more | Represents STEM (Science, Technology, Engineering, Math) principles – open ended toys to construct, engineer, explorer and experiment | Includes cross linked p ...
# --------------------------------------------------

# %%
qa_prompt = f'''{anthropic.HUMAN_PROMPT} You are a friendly product recommender. Here is a query issued by a user looking for product recommendations:

{query}

Here are a set of search results that might be helpful for answering the user's query:

{relevant_search_results}

Once again, here is the user's query:

<query>{query}</query>

Please write a response to the user that answers their query and provides them with helpful product recommendations. Feel free to use the search results above to help you write your response, or ignore them if they are not helpful.

At the end of your response, under "Products you might like:", list the top 3 product names from the search results that you think the user would most like.

Please ensure your results are in the following format:

<result>
Your response to the user's query.
</result>
<recommendations>
Products you might like:
1. Product name
2. Product name
3. Product name
</recommendations>{anthropic.AI_PROMPT}'''

response = client.completions.create(
    prompt=qa_prompt,
    stop_sequences=[anthropic.HUMAN_PROMPT],
    model=ANTHROPIC_SEARCH_MODEL,
    max_tokens_to_sample=1000,
)

print('-'*50)
print('Response:')
print(response.completion)
print('-'*50)
# Out:
# 2024-03-14 14:37:32,349 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# 2024-03-14 14:37:32,349 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/complete "HTTP/1.1 200 OK"
# --------------------------------------------------
# Response:
#  <result>
# Based on your goal of getting your daughter more interested in science, I would recommend getting her an engaging science kit or toy that allows her to conduct experiments and explore scientific concepts. The "Scientific Explorer My First Science Experiment Kit" seems like an excellent option that would spark her creativity and curiosity through hands-on activities like growing crystals, mixing colors, and more. This represents STEM principles that are great for kids to learn.
#
# Some other ideas would be an astronomy kit with a beginner telescope so she can gaze at planets and stars, a robotics/coding toy she can program, or a kids chemistry set to do safe experiments. Try to find kits that are open-ended to allow for discovery rather than just demonstrating a single scientific principle. Make it interactive and fun! Doing science experiments together would be a great bonding activity as well.
#
# I hope these recommendations give you some ideas to nurture your daughter's interest in science!
# </result>
#
# <recommendations>
# Products you might like:
# 1. Scientific Explorer My First Science Kids Science Experiment Kit
# 2. Scientific Explorer My First Science Kids Science Experiment Kit
# 3. Scientific Explorer My First Science Kids Science Experiment Kit
# </recommendations>
# --------------------------------------------------
